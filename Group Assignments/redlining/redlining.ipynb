# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
import networkx as nx
import osmnx as ox
import folium

# %%
geo = gpd.read_file('PAPhiladelphia1937.geojson')
shape = gpd.read_file('PAPhiladelphia1937 (1).zip')

# %%
geo.info()

# %%
shape.info()

# %%
geo.sample()

# %%
shape.sample()
# Out:
#     Name Home Owners Loan Corporation ID Grade  \
# 62  None                                   D21
#
#    Home Owners Loan Corporation Grade  \
# 62                                  D
#
#                                              Geometry
# 62  POLYGON ((-75.20851 39.94552, -75.20677 39.943...

# %%
shape.plot()
# Out:
# <AxesSubplot: >

# %%
shape.columns = ['Name',
                 'Home Owners Loan Corporation ID Grade',
                 'Home Owners Loan Corporation Grade',
                 'Geometry'
                ]

# %%
columns = list(shape)
columns
# Out:
# ['Name',
#  'Home Owners Loan Corporation ID Grade',
#  'Home Owners Loan Corporation Grade',
#  'Geometry']

# %%
shape.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 4 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Name                                   0 non-null      object
#  1   Home Owners Loan Corporation ID Grade  82 non-null     object
#  2   Home Owners Loan Corporation Grade     82 non-null     object
#  3   Geometry                               82 non-null     geometry
# dtypes: geometry(1), object(3)
# memory usage: 2.7+ KB

# %%
fig, ax = shape.subplots(figsize=(6,4))

for spine in plt.gca().spines.values():
    spine.set_visible(False)

shape.plot.bar(ax=ax,
                                      x='Home Owners Loan Corporation Grade',
                                      y='Name',
                                      legend=False,
                                      color='#1a4280ff',
                                       )
                                      
ax.set_ylabel('Home Owners Loan Corporation Grade') # override y label
plt.title("Types of Affordable Housing Projects"); # multi-line title with padding
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fig, ax = shape.subplots(figsize=(6,4))
#       3 for spine in plt.gca().spines.values():
#       4     spine.set_visible(False)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'GeoDataFrame' object has no attribute 'subplots'

# %%
logan_FIPS = ["42101028000", "42101028100", "42101028200", "42101028300", "42101028400", "42101028500"]

logan_tracts = tracts[tracts['FIPS'].isin(logan_FIPS)]

logan_boundary = logan_tracts.dissolve()

# %%
fig, ax = plt.subplots(figsize=(10,10))

df.to_crs(3857).plot(ax=ax,
marker='X',
markersize=20,
color='blue')

ax.axis('off')

ax.set_title('pa redlines')

ctx.add_basemap(ax, source=ctx.providers.Stamen.TonerLite)
