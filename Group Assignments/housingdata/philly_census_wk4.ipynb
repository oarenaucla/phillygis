# %% [markdown]
# ## **Exploration of Housing in Philadelphia with a focus on Logan Triangle**
# #### Author: Olivia Arena
#
# These data explore the current housing conditions in and around the Logan Triangle area of Philadelphia. Data are pulled from Census data and the Philadelphia Open Data Portal.

# %% [markdown]
# ### Set up

# %% [markdown]
# The initial steps in the process of importing and analyzing Census data require the importation of libraries to help spatially visualize the data downloaded from the Census Bureau. The first step in this process is to download pandas and geopandas libraries.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# We also need to import relevant data pulled from the Census bureau, including a dataset of housing tenure, housing costs, and census block groups from the most recent ACS. For our study area, which does not fit into a pre-identified census geographic designation, I compiled a few census tracts which could make up a study area. The census tracts are 280, 281, 282, 283, 284, and 285 in Philadelphia County, PA. An image of the study area (satellite) from Social Explorer is included below.

# %% [markdown]
# ![satellite_image_pa]('images/satelliteimage.png')

# %% [markdown]
# In Social Explorer, I chose to run a report pulling in 2017-2021 ACS 5-year data for Census Tracts 280, 281, 282, 283, 284, 285 in Philadelphia County, PA. I selected multiple housing variables including tenure and number of housing units. The command below reads in these data in a csv format into a new dataframe.

# %%
df = pd.read_csv('data/R13284958_SL140.csv')

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# After the initial import, several first steps include exploring these data to understand the shape and structure of the dataset.

# %%
df.shape
# Out:
# (6, 177)

# %%
df.head()
# Out:
#   Geo_FILEID Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  \
# 0      ACSSF         pa         140            0          9077     NaN
# 1      ACSSF         pa         140            0          9078     NaN
# 2      ACSSF         pa         140            0          9079     NaN
# 3      ACSSF         pa         140            0          9080     NaN
# 4      ACSSF         pa         140            0          9081     NaN
#
#    Geo_REGION  Geo_DIVISION  Geo_STATECE  Geo_STATE  ...  SE_A18001_009  \
# 0         NaN           NaN          NaN         42  ...              0
# 1         NaN           NaN          NaN         42  ...              0
# 2         NaN           NaN          NaN         42  ...              0
# 3         NaN           NaN          NaN         42  ...              0
# 4         NaN           NaN          NaN         42  ...              0
#
#    PCT_SE_A18001_002  PCT_SE_A18001_003  PCT_SE_A18001_004  PCT_SE_A18001_005  \
# 0              19.43               6.85               6.85              21.34
# 1               0.00              17.32               8.38              22.16
# 2               9.52               7.34               6.53              40.16
# 3               0.00               7.16              23.68              32.97
# 4              12.08              23.12               4.73              11.73
#
#    PCT_SE_A18001_006  PCT_SE_A18001_007  PCT_SE_A18001_008  PCT_SE_A18001_009  \
# 0              28.50              11.94               5.10                  0
# 1              17.69               6.15              28.31                  0
# 2              16.32               0.00              20.13                  0
# 3               9.36               8.89              17.94                  0
# 4              21.19              22.07               5.08                  0
#
#    SE_A18009_001
# 0            964
# 1           1030
# 2            953
# 3            925
# 4            886
#
# [5 rows x 177 columns]

# %% [markdown]
# Based on these initial exploratory commands, the dataset includes six rows (the six census tracts) and 218 columns, which likely includes all the specific intervals for each housing variable. For example, for the age of rental stock, the variable includes percentage of renter-occupied housing units built broken down by decade from 2019 to 1939 or earlier. So, there are nine variables that make up that specific indicator.

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 177 columns):
#  #    Column             Non-Null Count  Dtype
# ---   ------             --------------  -----
#  0    Geo_FILEID         6 non-null      object
#  1    Geo_STUSAB         6 non-null      object
#  2    Geo_SUMLEV         6 non-null      int64
#  3    Geo_GEOCOMP        6 non-null      int64
#  4    Geo_LOGRECNO       6 non-null      int64
#  5    Geo_US             0 non-null      float64
#  6    Geo_REGION         0 non-null      float64
#  7    Geo_DIVISION       0 non-null      float64
#  8    Geo_STATECE        0 non-null      float64
#  9    Geo_STATE          6 non-null      int64
#  10   Geo_COUNTY         6 non-null      int64
#  11   Geo_COUSUB         0 non-null      float64
#  12   Geo_PLACE          0 non-null      float64
#  13   Geo_TRACT          6 non-null      int64
#  14   Geo_BLKGRP         0 non-null      float64
#  15   Geo_CONCIT         0 non-null      float64
#  16   Geo_AIANHH         0 non-null      float64
#  17   Geo_AIANHHFP       0 non-null      float64
#  18   Geo_AIHHTLI        0 non-null      float64
#  19   Geo_AITSCE         0 non-null      float64
#  20   Geo_AITS           0 non-null      float64
#  21   Geo_ANRC           0 non-null      float64
#  22   Geo_CBSA           0 non-null      float64
#  23   Geo_CSA            0 non-null      float64
#  24   Geo_METDIV         0 non-null      float64
#  25   Geo_MACC           0 non-null      float64
#  26   Geo_MEMI           0 non-null      float64
#  27   Geo_NECTA          0 non-null      float64
#  28   Geo_CNECTA         0 non-null      float64
#  29   Geo_NECTADIV       0 non-null      float64
#  30   Geo_UA             0 non-null      float64
#  31   Geo_CDCURR         0 non-null      float64
#  32   Geo_SLDU           0 non-null      float64
#  33   Geo_SLDL           0 non-null      float64
#  34   Geo_ZCTA5          0 non-null      float64
#  35   Geo_SUBMCD         0 non-null      float64
#  36   Geo_SDELM          0 non-null      float64
#  37   Geo_SDSEC          0 non-null      float64
#  38   Geo_SDUNI          0 non-null      float64
#  39   Geo_UR             0 non-null      float64
#  40   Geo_PCI            0 non-null      float64
#  41   Geo_PUMA5          0 non-null      float64
#  42   Geo_GEOID          6 non-null      object
#  43   Geo_NAME           6 non-null      object
#  44   Geo_BTTR           0 non-null      float64
#  45   Geo_BTBG           0 non-null      float64
#  46   Geo_QName          6 non-null      object
#  47   Geo_FIPS           6 non-null      int64
#  48   Geo_AREALAND       6 non-null      int64
#  49   Geo_AREAWATR       6 non-null      int64
#  50   Geo_PLACESE        0 non-null      float64
#  51   Geo_UACP           0 non-null      float64
#  52   Geo_VTD            0 non-null      float64
#  53   Geo_ZCTA3          0 non-null      float64
#  54   Geo_TAZ            0 non-null      float64
#  55   Geo_UGA            0 non-null      float64
#  56   Geo_PUMA1          0 non-null      float64
#  57   SE_A10001_001      6 non-null      int64
#  58   SE_A00001_001      6 non-null      int64
#  59   SE_A10008_001      6 non-null      int64
#  60   SE_A10008_002      6 non-null      int64
#  61   SE_A10008_003      6 non-null      int64
#  62   SE_A10008_004      6 non-null      int64
#  63   SE_A10008_005      6 non-null      int64
#  64   SE_A10008_006      6 non-null      int64
#  65   SE_A10008_007      6 non-null      int64
#  66   SE_A10008_008      6 non-null      int64
#  67   SE_A10008_009      6 non-null      int64
#  68   PCT_SE_A10008_002  6 non-null      float64
#  69   PCT_SE_A10008_003  6 non-null      float64
#  70   PCT_SE_A10008_004  6 non-null      float64
#  71   PCT_SE_A10008_005  6 non-null      float64
#  72   PCT_SE_A10008_006  6 non-null      float64
#  73   PCT_SE_A10008_007  6 non-null      float64
#  74   PCT_SE_A10008_008  6 non-null      float64
#  75   PCT_SE_A10008_009  6 non-null      float64
#  76   SE_A10024_001      6 non-null      int64
#  77   SE_A10024_002      6 non-null      int64
#  78   SE_A10024_003      6 non-null      int64
#  79   SE_A10024_004      6 non-null      int64
#  80   SE_A10024_005      6 non-null      int64
#  81   SE_A10024_006      6 non-null      int64
#  82   SE_A10024_007      6 non-null      int64
#  83   SE_A10024_008      6 non-null      int64
#  84   PCT_SE_A10024_002  6 non-null      float64
#  85   PCT_SE_A10024_003  6 non-null      float64
#  86   PCT_SE_A10024_004  6 non-null      float64
#  87   PCT_SE_A10024_005  6 non-null      float64
#  88   PCT_SE_A10024_006  6 non-null      float64
#  89   PCT_SE_A10024_007  6 non-null      float64
#  90   PCT_SE_A10024_008  6 non-null      float64
#  91   SE_A10003_001      6 non-null      float64
#  92   SE_A10060_001      6 non-null      int64
#  93   SE_A10060_002      6 non-null      int64
#  94   SE_A10060_003      6 non-null      int64
#  95   PCT_SE_A10060_002  6 non-null      float64
#  96   PCT_SE_A10060_003  6 non-null      float64
#  97   SE_B10060_001      6 non-null      int64
#  98   SE_B10060_002      6 non-null      int64
#  99   SE_B10060_003      6 non-null      int64
#  100  PCT_SE_B10060_002  6 non-null      float64
#  101  PCT_SE_B10060_003  6 non-null      float64
#  102  SE_A10044_001      6 non-null      int64
#  103  SE_A10044_002      6 non-null      int64
#  104  SE_A10044_003      6 non-null      int64
#  105  PCT_SE_A10044_002  6 non-null      float64
#  106  PCT_SE_A10044_003  6 non-null      float64
#  107  SE_A10047_001      6 non-null      int64
#  108  SE_A10047_002      6 non-null      int64
#  109  SE_A10047_003      6 non-null      int64
#  110  SE_A10047_004      6 non-null      int64
#  111  PCT_SE_A10047_002  6 non-null      float64
#  112  PCT_SE_A10047_003  6 non-null      float64
#  113  PCT_SE_A10047_004  6 non-null      float64
#  114  SE_A10032_001      6 non-null      int64
#  115  SE_A10032_002      6 non-null      int64
#  116  SE_A10032_003      6 non-null      int64
#  117  SE_A10032_004      6 non-null      int64
#  118  SE_A10032_005      6 non-null      int64
#  119  SE_A10032_006      6 non-null      int64
#  120  SE_A10032_007      6 non-null      int64
#  121  SE_A10032_008      6 non-null      int64
#  122  SE_A10032_009      6 non-null      int64
#  123  SE_A10032_010      6 non-null      int64
#  124  SE_A10032_011      6 non-null      int64
#  125  SE_A10032_012      6 non-null      int64
#  126  PCT_SE_A10032_002  6 non-null      float64
#  127  PCT_SE_A10032_003  6 non-null      float64
#  128  PCT_SE_A10032_004  6 non-null      float64
#  129  PCT_SE_A10032_005  6 non-null      float64
#  130  PCT_SE_A10032_006  6 non-null      float64
#  131  PCT_SE_A10032_007  6 non-null      float64
#  132  PCT_SE_A10032_008  6 non-null      float64
#  133  PCT_SE_A10032_009  6 non-null      float64
#  134  PCT_SE_A10032_010  6 non-null      float64
#  135  PCT_SE_A10032_011  6 non-null      int64
#  136  PCT_SE_A10032_012  6 non-null      int64
#  137  SE_A10055_001      6 non-null      int64
#  138  SE_A10055_002      6 non-null      int64
#  139  SE_A10055_003      6 non-null      int64
#  140  SE_A10055_004      6 non-null      int64
#  141  SE_A10055_005      6 non-null      int64
#  142  SE_A10055_006      6 non-null      int64
#  143  SE_A10055_007      6 non-null      int64
#  144  SE_A10055_008      6 non-null      int64
#  145  SE_A10055_009      6 non-null      int64
#  146  SE_A10055_010      6 non-null      int64
#  147  SE_A10055_011      6 non-null      int64
#  148  PCT_SE_A10055_002  6 non-null      int64
#  149  PCT_SE_A10055_003  6 non-null      float64
#  150  PCT_SE_A10055_004  6 non-null      float64
#  151  PCT_SE_A10055_005  6 non-null      float64
#  152  PCT_SE_A10055_006  6 non-null      float64
#  153  PCT_SE_A10055_007  6 non-null      float64
#  154  PCT_SE_A10055_008  6 non-null      float64
#  155  PCT_SE_A10055_009  6 non-null      float64
#  156  PCT_SE_A10055_010  6 non-null      float64
#  157  PCT_SE_A10055_011  6 non-null      float64
#  158  SE_A10036_001      6 non-null      int64
#  159  SE_A18001_001      6 non-null      int64
#  160  SE_A18001_002      6 non-null      int64
#  161  SE_A18001_003      6 non-null      int64
#  162  SE_A18001_004      6 non-null      int64
#  163  SE_A18001_005      6 non-null      int64
#  164  SE_A18001_006      6 non-null      int64
#  165  SE_A18001_007      6 non-null      int64
#  166  SE_A18001_008      6 non-null      int64
#  167  SE_A18001_009      6 non-null      int64
#  168  PCT_SE_A18001_002  6 non-null      float64
#  169  PCT_SE_A18001_003  6 non-null      float64
#  170  PCT_SE_A18001_004  6 non-null      float64
#  171  PCT_SE_A18001_005  6 non-null      float64
#  172  PCT_SE_A18001_006  6 non-null      float64
#  173  PCT_SE_A18001_007  6 non-null      float64
#  174  PCT_SE_A18001_008  6 non-null      float64
#  175  PCT_SE_A18001_009  6 non-null      int64
#  176  SE_A18009_001      6 non-null      int64
# dtypes: float64(93), int64(79), object(5)
# memory usage: 8.4+ KB

# %% [markdown]
# As expected, the number of variables is so high because of the specific increments in which the indicators are broken down. This may become an issue later on, and it might be necessary to subset the data.
#
# I will need to ensure that the variables for the geographies are read in as strings rather than objects, so I am going to use code to read in the two files that I will use to append to geographic data. The first file, which was initially read in, has housing data for the census tracts that make up the Logan Neighborhood.

# %%
df = pd.read_csv(
    'data/R13284958_SL140.csv',
    dtype=
    {
        'Geo_STATE':str,
        'Geo_COUNTY': str,
        'Geo_TRACT':str, 
        'Geo_FIPS':str
    }
)

# %% [markdown]
# The second file has data for the entire Philadelphia County. By comparing the two geographies, I hope to be able to contextualize the housing patterns in the Logan Neighborhood, compared with Philadelphia as a whole.

# %%
dfpa = pd.read_csv(
    'data/R13285245_SL140.csv',
    dtype=
    {
        'Geo_STATE':str,
        'Geo_COUNTY': str,
        'Geo_TRACT':str, 
        'Geo_FIPS':str
    }
)

# %%
df.Geo_STATE.head()
# Out:
# 0    42
# 1    42
# 2    42
# 3    42
# 4    42
# Name: Geo_STATE, dtype: object

# %%
df.Geo_FIPS
# Out:
# 0    42101028000
# 1    42101028100
# 2    42101028200
# 3    42101028300
# 4    42101028400
# 5    42101028500
# Name: Geo_FIPS, dtype: object

# %%
df.shape
# Out:
# (6, 177)

# %% [markdown]
# Now, I want to drop variables that have no data.

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_PUMA5',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE',
#  'Geo_UACP',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA1']

# %%
df = df.dropna(axis=1,how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Columns: 134 entries, Geo_FILEID to SE_A18009_001
# dtypes: float64(50), int64(75), object(9)
# memory usage: 6.4+ KB

# %% [markdown]
# Here it looks like the values dropped from 177 variables to 134. However, I wonder if that is because these were variable categories, like % owner, that just had no data. This issue may be something to come back to.

# %% [markdown]
# This section of work looks at tenure for housing units, and I would like to keep occupied units by owner and renter  : Tenure
#          Universe:  Occupied Housing Units
#          Name:      A10060
#          Variables:
#             A10060_001:   Occupied Housing Units:
#             A10060_002:      Owner Occupied
#             A10060_003:      Renter Occupied

# %%
columns_to_keep = ['Geo_FIPS',
                   'SE_A10008_001',
                   'SE_A10008_002',
                   'SE_A10008_003',
                   'SE_A10008_004',
                   'SE_A10008_005',
                   'SE_A10008_006',
                   'SE_A10008_007',
                   'SE_A10008_008',
                   'SE_A10008_009',
                   'SE_A10003_001',
                   'SE_B10060_001',
                   'SE_B10060_002',
                   'SE_B10060_003',
                   'SE_A10036_001',
                   'SE_A18009_001',
                   'SE_A10032_001',
                   'SE_A10032_002',
                   'SE_A10032_003',
                   'SE_A10032_004',
                   'SE_A10032_005',
                   'SE_A10032_006',
                   'SE_A10032_007',
                   'SE_A10032_008',
                   'SE_A10032_009',
                   'SE_A10032_010',
                   'SE_A10032_011',
                   'SE_A10032_012',
                   'SE_A10055_001',
                   'SE_A10055_002',
                   'SE_A10055_003',
                   'SE_A10055_004',
                   'SE_A10055_005',
                   'SE_A10055_006',
                   'SE_A10055_007',
                   'SE_A10055_008',
                   'SE_A10055_009',
                   'SE_A10055_010',
                   'SE_A10055_011',]

# %%
df2 = df[columns_to_keep]

# %% [markdown]
# Because I just created a new subset of the data and added it to a new dataframe, I want to double check my work. I kept variables related to housing including the categories below:
#
# * Housing Units
# * Households by Household Type
# * White vs Non-White Homeowners (owner-occupied units)
# * Occupied housing units by year built 1939 to 2000
# * Housing Units (by number and include mobile homes and boats)
# Average Household Size (Occupied households)

# %%
df2.head()
# Out:
#       Geo_FIPS  SE_A10008_001  SE_A10008_002  SE_A10008_003  SE_A10008_004  \
# 0  42101028000           1735           1016            585            431
# 1  42101028100           1917           1062            254            808
# 2  42101028200           2216           1029            486            543
# 3  42101028300           2532           1248            401            847
# 4  42101028400           1363            891            148            743
#
#    SE_A10008_005  SE_A10008_006  SE_A10008_007  SE_A10008_008  SE_A10008_009  \
# 0             71            360            719            466            253
# 1            331            477            855            216            639
# 2              0            543           1187            403            784
# 3              5            842           1284            578            706
# 4             89            654            472            148            324
#
#    ...  SE_A10055_002  SE_A10055_003  SE_A10055_004  SE_A10055_005  \
# 0  ...              0             57              0             15
# 1  ...              0              0             87              0
# 2  ...              0              0             37             14
# 3  ...              0              0              0              5
# 4  ...              0              0              0              0
#
#    SE_A10055_006  SE_A10055_007  SE_A10055_008  SE_A10055_009  SE_A10055_010  \
# 0             90             76             88             77            320
# 1              0             81             75            178            130
# 2            118            112            611            289            259
# 3              0             78            204            736            331
# 4             11             72             79            205            371
#
#    SE_A10055_011
# 0           1012
# 1           1366
# 2            776
# 3           1178
# 4            625
#
# [5 rows x 39 columns]

# %%
1107+628
# Out:
# 1735

# %% [markdown]
# In testing the math on row 0, it does look like the two variables kept do add up to one another (renter and owner = total occupied units). Now I am going to rename my columns to reflect the variable names in the data dictionary.

# %%
df2.columns = ['FIPS',
                   'Households',
                   'Family Households',
                   'Married-Couple Family',
                   'Other Family',
                   'Male Householder, No Wife Present',
                   'Female Householder, No Husband Present',
                   'Nonfamily Households',
                   'Male Householder',
                   'Female Householder',
                   'Average Household Size of Occupied Housing Units',
                   'Owner Occupied Housing Units',
                   'White Alone, Not Hispanic or Latino Homeowners of Owner Occupied Housing Units',
                   'Non-White Homeowners of Owner Occupied Housing Units',
                   'Median House Value for All Owner-Occupied Housing Units',
                   'Median Gross Rent in Renter-occupied housing units paying cash rent',
                   'Housing Units',
                   '1 Unit',
                   '1 Unit, Detached',
                   '1 Unit, Attached',
                   '2 Units',
                   '3 or 4 Units',
                   '5 to 9 Units',
                   '10 to 19 Units',
                   '20 to 49 Units',
                   '50 or More Units',
                   'Mobile Home',
                   'Boat, Rv, Van, Etc.',
                   'Occupied Housing Units',
                   'Occupied Housing Units: Built 2020 or Later',
                   'Occupied Housing Units: Built 2010 to 2019',
                   'Occupied Housing Units: Built 2000 to 2009',
                   'Occupied Housing Units: Built 1990 to 1999',
                   'Occupied Housing Units: Built 1980 to 1989',
                   'Occupied Housing Units: Built 1970 to 1979',
                   'Occupied Housing Units: Built 1960 to 1969',
                   'Occupied Housing Units: Built 1950 to 1959',
                   'Occupied Housing Units: Built 1940 to 1949',
                   'Occupied Housing Units: Built 1939 or Earlier',]

# %%
columns = list(df2)
columns
# Out:
# ['FIPS',
#  'Households',
#  'Family Households',
#  'Married-Couple Family',
#  'Other Family',
#  'Male Householder, No Wife Present',
#  'Female Householder, No Husband Present',
#  'Nonfamily Households',
#  'Male Householder',
#  'Female Householder',
#  'Average Household Size of Occupied Housing Units',
#  'Owner Occupied Housing Units',
#  'White Alone, Not Hispanic or Latino Homeowners of Owner Occupied Housing Units',
#  'Non-White Homeowners of Owner Occupied Housing Units',
#  'Median House Value for All Owner-Occupied Housing Units',
#  'Median Gross Rent in Renter-occupied housing units paying cash rent',
#  'Housing Units',
#  '1 Unit',
#  '1 Unit, Detached',
#  '1 Unit, Attached',
#  '2 Units',
#  '3 or 4 Units',
#  '5 to 9 Units',
#  '10 to 19 Units',
#  '20 to 49 Units',
#  '50 or More Units',
#  'Mobile Home',
#  'Boat, Rv, Van, Etc.',
#  'Occupied Housing Units',
#  'Occupied Housing Units: Built 2020 or Later',
#  'Occupied Housing Units: Built 2010 to 2019',
#  'Occupied Housing Units: Built 2000 to 2009',
#  'Occupied Housing Units: Built 1990 to 1999',
#  'Occupied Housing Units: Built 1980 to 1989',
#  'Occupied Housing Units: Built 1970 to 1979',
#  'Occupied Housing Units: Built 1960 to 1969',
#  'Occupied Housing Units: Built 1950 to 1959',
#  'Occupied Housing Units: Built 1940 to 1949',
#  'Occupied Housing Units: Built 1939 or Earlier']

# %% [markdown]
# Now, I want to take a look to make sure these variable names were added to the columns wihtout error.

# %%
df2.sample(5)
# Out:
#           FIPS  Households  Family Households  Married-Couple Family  \
# 2  42101028200        2216               1029                    486
# 4  42101028400        1363                891                    148
# 1  42101028100        1917               1062                    254
# 0  42101028000        1735               1016                    585
# 5  42101028500        1116                416                     97
#
#    Other Family  Male Householder, No Wife Present  \
# 2           543                                  0
# 4           743                                 89
# 1           808                                331
# 0           431                                 71
# 5           319                                 85
#
#    Female Householder, No Husband Present  Nonfamily Households  \
# 2                                     543                  1187
# 4                                     654                   472
# 1                                     477                   855
# 0                                     360                   719
# 5                                     234                   700
#
#    Male Householder  Female Householder  ...  \
# 2               403                 784  ...
# 4               148                 324  ...
# 1               216                 639  ...
# 0               466                 253  ...
# 5               148                 552  ...
#
#    Occupied Housing Units: Built 2020 or Later  \
# 2                                            0
# 4                                            0
# 1                                            0
# 0                                            0
# 5                                            0
#
#    Occupied Housing Units: Built 2010 to 2019  \
# 2                                           0
# 4                                           0
# 1                                           0
# 0                                          57
# 5                                           0
#
#    Occupied Housing Units: Built 2000 to 2009  \
# 2                                          37
# 4                                           0
# 1                                          87
# 0                                           0
# 5                                           0
#
#    Occupied Housing Units: Built 1990 to 1999  \
# 2                                          14
# 4                                           0
# 1                                           0
# 0                                          15
# 5                                          58
#
#    Occupied Housing Units: Built 1980 to 1989  \
# 2                                         118
# 4                                          11
# 1                                           0
# 0                                          90
# 5                                          60
#
#    Occupied Housing Units: Built 1970 to 1979  \
# 2                                         112
# 4                                          72
# 1                                          81
# 0                                          76
# 5                                          19
#
#    Occupied Housing Units: Built 1960 to 1969  \
# 2                                         611
# 4                                          79
# 1                                          75
# 0                                          88
# 5                                          82
#
#    Occupied Housing Units: Built 1950 to 1959  \
# 2                                         289
# 4                                         205
# 1                                         178
# 0                                          77
# 5                                         103
#
#    Occupied Housing Units: Built 1940 to 1949  \
# 2                                         259
# 4                                         371
# 1                                         130
# 0                                         320
# 5                                         151
#
#    Occupied Housing Units: Built 1939 or Earlier
# 2                                            776
# 4                                            625
# 1                                           1366
# 0                                           1012
# 5                                            643
#
# [5 rows x 39 columns]

# %%
df2['Housing Units'].describe()
# Out:
# count       6.000000
# mean     1982.666667
# std       621.644486
# min      1174.000000
# 25%      1599.750000
# 50%      1983.500000
# 75%      2264.500000
# max      2925.000000
# Name: Housing Units, dtype: float64

# %%
df2.boxplot(column=['Housing Units'])

plt.show()

# %% [markdown]
# Looking at the graph above, it looks like the highest number of renters is in Census tract 283, followed by 282. THese figures are much higher than the other three Census tracts. When we get to the mapping component, it will be interesting to see what the dividing line is.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 39 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   FIPS                                                                            6 non-null      object
#  1   Households                                                                      6 non-null      int64
#  2   Family Households                                                               6 non-null      int64
#  3   Married-Couple Family                                                           6 non-null      int64
#  4   Other Family                                                                    6 non-null      int64
#  5   Male Householder, No Wife Present                                               6 non-null      int64
#  6   Female Householder, No Husband Present                                          6 non-null      int64
#  7   Nonfamily Households                                                            6 non-null      int64
#  8   Male Householder                                                                6 non-null      int64
#  9   Female Householder                                                              6 non-null      int64
#  10  Average Household Size of Occupied Housing Units                                6 non-null      float64
#  11  Owner Occupied Housing Units                                                    6 non-null      int64
#  12  White Alone, Not Hispanic or Latino Homeowners of Owner Occupied Housing Units  6 non-null      int64
#  13  Non-White Homeowners of Owner Occupied Housing Units                            6 non-null      int64
#  14  Median House Value for All Owner-Occupied Housing Units                         6 non-null      int64
#  15  Median Gross Rent in Renter-occupied housing units paying cash rent             6 non-null      int64
#  16  Housing Units                                                                   6 non-null      int64
#  17  1 Unit                                                                          6 non-null      int64
#  18  1 Unit, Detached                                                                6 non-null      int64
#  19  1 Unit, Attached                                                                6 non-null      int64
#  20  2 Units                                                                         6 non-null      int64
#  21  3 or 4 Units                                                                    6 non-null      int64
#  22  5 to 9 Units                                                                    6 non-null      int64
#  23  10 to 19 Units                                                                  6 non-null      int64
#  24  20 to 49 Units                                                                  6 non-null      int64
#  25  50 or More Units                                                                6 non-null      int64
#  26  Mobile Home                                                                     6 non-null      int64
#  27  Boat, Rv, Van, Etc.                                                             6 non-null      int64
#  28  Occupied Housing Units                                                          6 non-null      int64
#  29  Occupied Housing Units: Built 2020 or Later                                     6 non-null      int64
#  30  Occupied Housing Units: Built 2010 to 2019                                      6 non-null      int64
#  31  Occupied Housing Units: Built 2000 to 2009                                      6 non-null      int64
#  32  Occupied Housing Units: Built 1990 to 1999                                      6 non-null      int64
#  33  Occupied Housing Units: Built 1980 to 1989                                      6 non-null      int64
#  34  Occupied Housing Units: Built 1970 to 1979                                      6 non-null      int64
#  35  Occupied Housing Units: Built 1960 to 1969                                      6 non-null      int64
#  36  Occupied Housing Units: Built 1950 to 1959                                      6 non-null      int64
#  37  Occupied Housing Units: Built 1940 to 1949                                      6 non-null      int64
#  38  Occupied Housing Units: Built 1939 or Earlier                                   6 non-null      int64
# dtypes: float64(1), int64(37), object(1)
# memory usage: 2.0+ KB

# %% [markdown]
# ### Importing geographic data for mapping

# %% [markdown]
# Now, I will import the geographic data to be able to map the Census data on specific rtacts and visualize some of the patterns within Philadelphia.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# I found a geojson file with Philadelphia Census Tracts from 2010 on the Philadelphia Open Data Portal. I am reading in the file for all of Philadelphia. Depending on the ACS dataset, I will either subset specific tracts or I will use all of the tracks in Philadelphia for comparison.

# %%
tracts=gpd.read_file('data/Census_Tracts_2010.geojson')
tracts.head()
# Out:
#    OBJECTID STATEFP10 COUNTYFP10 TRACTCE10      GEOID10 NAME10  \
# 0         1        42        101    009400  42101009400     94
# 1         2        42        101    009500  42101009500     95
# 2         3        42        101    009600  42101009600     96
# 3         4        42        101    013800  42101013800    138
# 4         5        42        101    013900  42101013900    139
#
#          NAMELSAD10 MTFCC10 FUNCSTAT10  ALAND10  AWATER10   INTPTLAT10  \
# 0   Census Tract 94   G5020          S   366717         0  +39.9632709
# 1   Census Tract 95   G5020          S   319070         0  +39.9658709
# 2   Census Tract 96   G5020          S   405273         0  +39.9655396
# 3  Census Tract 138   G5020          S   341256         0  +39.9764504
# 4  Census Tract 139   G5020          S   562934         0  +39.9750563
#
#      INTPTLON10 LOGRECNO                                           geometry
# 0  -075.2322437    10429  POLYGON ((-75.22927 39.96054, -75.22865 39.960...
# 1  -075.2379140    10430  POLYGON ((-75.23536 39.96852, -75.23545 39.969...
# 2  -075.2435075    10431  POLYGON ((-75.24343 39.96230, -75.24339 39.962...
# 3  -075.1771771    10468  POLYGON ((-75.17341 39.97779, -75.17386 39.977...
# 4  -075.1711846    10469  POLYGON ((-75.17313 39.97776, -75.17321 39.977...

# %% [markdown]
# Now that the geometric data has been imported, I will run an initial plot to begin visualizing.

# %%
tracts.plot(figsize=(12,10))
plt.show()

# %% [markdown]
# The map above shows all of Philadelphia, PA!

# %%
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    384 non-null    int64
#  1   STATEFP10   384 non-null    object
#  2   COUNTYFP10  384 non-null    object
#  3   TRACTCE10   384 non-null    object
#  4   GEOID10     384 non-null    object
#  5   NAME10      384 non-null    object
#  6   NAMELSAD10  384 non-null    object
#  7   MTFCC10     384 non-null    object
#  8   FUNCSTAT10  384 non-null    object
#  9   ALAND10     384 non-null    int64
#  10  AWATER10    384 non-null    int64
#  11  INTPTLAT10  384 non-null    object
#  12  INTPTLON10  384 non-null    object
#  13  LOGRECNO    384 non-null    object
#  14  geometry    384 non-null    geometry
# dtypes: geometry(1), int64(3), object(11)
# memory usage: 45.1+ KB

# %% [markdown]
# Now, I want to subset this dataset to only include the two variables that I need, which are the FIPS code (for joining) and the geometry (for spatial visualizing). I am dropping all variables except for the tract variable (TRACTCE9=10) and the geometry variable.

# %%
tracts = tracts[['TRACTCE10','geometry']]
tracts.head()
# Out:
#   TRACTCE10                                           geometry
# 0    009400  POLYGON ((-75.22927 39.96054, -75.22865 39.960...
# 1    009500  POLYGON ((-75.23536 39.96852, -75.23545 39.969...
# 2    009600  POLYGON ((-75.24343 39.96230, -75.24339 39.962...
# 3    013800  POLYGON ((-75.17341 39.97779, -75.17386 39.977...
# 4    013900  POLYGON ((-75.17313 39.97776, -75.17321 39.977...

# %% [markdown]
# As explained above, to get the full FIPS code for the tract, I will need the state and city codes for Philadelphia. Then, I will merge these codes to the specific tract codes.

# %%
tracts['FIPS'] ='42' + '101' + tracts['TRACTCE10']

# %% [markdown]
# I wanted to make sure that the new variable was created, so I printed and below I tried it the way it is written in the lab notes.

# %%
print(tracts)
# Out:
#     TRACTCE10                                           geometry         FIPS
# 0      009400  POLYGON ((-75.22927 39.96054, -75.22865 39.960...  42101009400
# 1      009500  POLYGON ((-75.23536 39.96852, -75.23545 39.969...  42101009500
# 2      009600  POLYGON ((-75.24343 39.96230, -75.24339 39.962...  42101009600
# 3      013800  POLYGON ((-75.17341 39.97779, -75.17386 39.977...  42101013800
# 4      013900  POLYGON ((-75.17313 39.97776, -75.17321 39.977...  42101013900
# ..        ...                                                ...          ...
# 379    037200  POLYGON ((-75.17135 39.91678, -75.17143 39.916...  42101037200
# 380    038300  POLYGON ((-75.11627 40.01743, -75.11660 40.017...  42101038300
# 381    039000  POLYGON ((-75.08824 40.04034, -75.08820 40.040...  42101039000
# 382    037800  POLYGON ((-75.11051 39.96952, -75.10676 39.970...  42101037800
# 383    037700  POLYGON ((-75.15170 39.98571, -75.15249 39.985...  42101037700
#
# [384 rows x 3 columns]

# %%
tracts.head()
# Out:
#   TRACTCE10                                           geometry         FIPS
# 0    009400  POLYGON ((-75.22927 39.96054, -75.22865 39.960...  42101009400
# 1    009500  POLYGON ((-75.23536 39.96852, -75.23545 39.969...  42101009500
# 2    009600  POLYGON ((-75.24343 39.96230, -75.24339 39.962...  42101009600
# 3    013800  POLYGON ((-75.17341 39.97779, -75.17386 39.977...  42101013800
# 4    013900  POLYGON ((-75.17313 39.97776, -75.17321 39.977...  42101013900

# %%
df2.head()
# Out:
#           FIPS  Households  Family Households  Married-Couple Family  \
# 0  42101028000        1735               1016                    585
# 1  42101028100        1917               1062                    254
# 2  42101028200        2216               1029                    486
# 3  42101028300        2532               1248                    401
# 4  42101028400        1363                891                    148
#
#    Other Family  Male Householder, No Wife Present  \
# 0           431                                 71
# 1           808                                331
# 2           543                                  0
# 3           847                                  5
# 4           743                                 89
#
#    Female Householder, No Husband Present  Nonfamily Households  \
# 0                                     360                   719
# 1                                     477                   855
# 2                                     543                  1187
# 3                                     842                  1284
# 4                                     654                   472
#
#    Male Householder  Female Householder  ...  \
# 0               466                 253  ...
# 1               216                 639  ...
# 2               403                 784  ...
# 3               578                 706  ...
# 4               148                 324  ...
#
#    Occupied Housing Units: Built 2020 or Later  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    Occupied Housing Units: Built 2010 to 2019  \
# 0                                          57
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Occupied Housing Units: Built 2000 to 2009  \
# 0                                           0
# 1                                          87
# 2                                          37
# 3                                           0
# 4                                           0
#
#    Occupied Housing Units: Built 1990 to 1999  \
# 0                                          15
# 1                                           0
# 2                                          14
# 3                                           5
# 4                                           0
#
#    Occupied Housing Units: Built 1980 to 1989  \
# 0                                          90
# 1                                           0
# 2                                         118
# 3                                           0
# 4                                          11
#
#    Occupied Housing Units: Built 1970 to 1979  \
# 0                                          76
# 1                                          81
# 2                                         112
# 3                                          78
# 4                                          72
#
#    Occupied Housing Units: Built 1960 to 1969  \
# 0                                          88
# 1                                          75
# 2                                         611
# 3                                         204
# 4                                          79
#
#    Occupied Housing Units: Built 1950 to 1959  \
# 0                                          77
# 1                                         178
# 2                                         289
# 3                                         736
# 4                                         205
#
#    Occupied Housing Units: Built 1940 to 1949  \
# 0                                         320
# 1                                         130
# 2                                         259
# 3                                         331
# 4                                         371
#
#    Occupied Housing Units: Built 1939 or Earlier
# 0                                           1012
# 1                                           1366
# 2                                            776
# 3                                           1178
# 4                                            625
#
# [5 rows x 39 columns]

# %% [markdown]
# Having imported the geographic data and created the FIPS variable that will enable me to merge the two files, it is time to merge. I merge the file with geometry to the file of ACS with housing data into a new file "tracts_tenure."

# %%
tracts_housing= tracts.merge(df2,on='FIPS')
#tracts_tenure = df2.merge(tracts,on='FIPS')

# %% [markdown]
# Now I want to see how the merge worked!

# %%
tracts_tenure.head()
# Out:
#   TRACTCE10                                           geometry         FIPS  \
# 0    028300  POLYGON ((-75.14169 40.02076, -75.14159 40.020...  42101028300
# 1    028400  POLYGON ((-75.13571 40.02392, -75.13555 40.026...  42101028400
# 2    028500  POLYGON ((-75.13527 40.02919, -75.13541 40.027...  42101028500
# 3    028000  POLYGON ((-75.15385 40.02217, -75.15336 40.022...  42101028000
# 4    028100  POLYGON ((-75.14658 40.03065, -75.14652 40.030...  42101028100
#
#    Households  Family Households  Married-Couple Family  Other Family  \
# 0        2532               1248                    401           847
# 1        1363                891                    148           743
# 2        1116                416                     97           319
# 3        1735               1016                    585           431
# 4        1917               1062                    254           808
#
#    Male Householder, No Wife Present  Female Householder, No Husband Present  \
# 0                                  5                                     842
# 1                                 89                                     654
# 2                                 85                                     234
# 3                                 71                                     360
# 4                                331                                     477
#
#    Nonfamily Households  ...  Occupied Housing Units: Built 2020 or Later  \
# 0                  1284  ...                                            0
# 1                   472  ...                                            0
# 2                   700  ...                                            0
# 3                   719  ...                                            0
# 4                   855  ...                                            0
#
#    Occupied Housing Units: Built 2010 to 2019  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                          57
# 4                                           0
#
#    Occupied Housing Units: Built 2000 to 2009  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                          87
#
#    Occupied Housing Units: Built 1990 to 1999  \
# 0                                           5
# 1                                           0
# 2                                          58
# 3                                          15
# 4                                           0
#
#    Occupied Housing Units: Built 1980 to 1989  \
# 0                                           0
# 1                                          11
# 2                                          60
# 3                                          90
# 4                                           0
#
#    Occupied Housing Units: Built 1970 to 1979  \
# 0                                          78
# 1                                          72
# 2                                          19
# 3                                          76
# 4                                          81
#
#    Occupied Housing Units: Built 1960 to 1969  \
# 0                                         204
# 1                                          79
# 2                                          82
# 3                                          88
# 4                                          75
#
#    Occupied Housing Units: Built 1950 to 1959  \
# 0                                         736
# 1                                         205
# 2                                         103
# 3                                          77
# 4                                         178
#
#    Occupied Housing Units: Built 1940 to 1949  \
# 0                                         331
# 1                                         371
# 2                                         151
# 3                                         320
# 4                                         130
#
#    Occupied Housing Units: Built 1939 or Earlier
# 0                                           1178
# 1                                            625
# 2                                            643
# 3                                           1012
# 4                                           1366
#
# [5 rows x 41 columns]

# %%
tracts_tenure.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 6 entries, 0 to 5
# Data columns (total 41 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   TRACTCE10                                                                       6 non-null      object
#  1   geometry                                                                        6 non-null      geometry
#  2   FIPS                                                                            6 non-null      object
#  3   Households                                                                      6 non-null      int64
#  4   Family Households                                                               6 non-null      int64
#  5   Married-Couple Family                                                           6 non-null      int64
#  6   Other Family                                                                    6 non-null      int64
#  7   Male Householder, No Wife Present                                               6 non-null      int64
#  8   Female Householder, No Husband Present                                          6 non-null      int64
#  9   Nonfamily Households                                                            6 non-null      int64
#  10  Male Householder                                                                6 non-null      int64
#  11  Female Householder                                                              6 non-null      int64
#  12  Average Household Size of Occupied Housing Units                                6 non-null      float64
#  13  Owner Occupied Housing Units                                                    6 non-null      int64
#  14  White Alone, Not Hispanic or Latino Homeowners of Owner Occupied Housing Units  6 non-null      int64
#  15  Non-White Homeowners of Owner Occupied Housing Units                            6 non-null      int64
#  16  Median House Value for All Owner-Occupied Housing Units                         6 non-null      int64
#  17  Median Gross Rent in Renter-occupied housing units paying cash rent             6 non-null      int64
#  18  Housing Units                                                                   6 non-null      int64
#  19  1 Unit                                                                          6 non-null      int64
#  20  1 Unit, Detached                                                                6 non-null      int64
#  21  1 Unit, Attached                                                                6 non-null      int64
#  22  2 Units                                                                         6 non-null      int64
#  23  3 or 4 Units                                                                    6 non-null      int64
#  24  5 to 9 Units                                                                    6 non-null      int64
#  25  10 to 19 Units                                                                  6 non-null      int64
#  26  20 to 49 Units                                                                  6 non-null      int64
#  27  50 or More Units                                                                6 non-null      int64
#  28  Mobile Home                                                                     6 non-null      int64
#  29  Boat, Rv, Van, Etc.                                                             6 non-null      int64
#  30  Occupied Housing Units                                                          6 non-null      int64
#  31  Occupied Housing Units: Built 2020 or Later                                     6 non-null      int64
#  32  Occupied Housing Units: Built 2010 to 2019                                      6 non-null      int64
#  33  Occupied Housing Units: Built 2000 to 2009                                      6 non-null      int64
#  34  Occupied Housing Units: Built 1990 to 1999                                      6 non-null      int64
#  35  Occupied Housing Units: Built 1980 to 1989                                      6 non-null      int64
#  36  Occupied Housing Units: Built 1970 to 1979                                      6 non-null      int64
#  37  Occupied Housing Units: Built 1960 to 1969                                      6 non-null      int64
#  38  Occupied Housing Units: Built 1950 to 1959                                      6 non-null      int64
#  39  Occupied Housing Units: Built 1940 to 1949                                      6 non-null      int64
#  40  Occupied Housing Units: Built 1939 or Earlier                                   6 non-null      int64
# dtypes: float64(1), geometry(1), int64(37), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# The benefit of including geographic data is to be able to map, so I am going to try out a quick plot of the number of renter occupied units with natural breaks in the data to mark different colors.

# %%
tracts_tenure.plot(figsize=(12,10),
                 column='Housing Units',
                 legend=True, 
                 scheme='equal_interval')
plt.show()

# %% [markdown]
# Again, using equal intervals, the two census tracts (283 and 282) have the highest number of renters.

# %%
tracts_housing.plot()
plt.show()

# %% [markdown]
# Now, I want to compare the number of renters in a more proportional way. It's helpful to see the number of renters across the tracts, but what does it mean in the context of tenure? Are more places rented or owner occupied? What is the context for the specific numbers? I am going to make a new variable for both renters and owners that is the percentage of renter occupied or owner occupied units out of the total number of occupied housing units.

# %%
tracts_tenure['PCT_Renter'] = tracts_tenure['Renter Occupied']/tracts_tenure['Occupied Housing Units']*100
tracts_tenure['PCT_Owner'] = tracts_tenure['Owner Occupied']/tracts_tenure['Occupied Housing Units']*100

# %% [markdown]
# Now, I hope to try visualizing these data, starting by first looking at the percentages. They range form 30% to 51% renters. So across the board, these tracts are either equally renter and owner or mostly owner.

# %%
tracts_tenure['PCT_Renter'].head()
# Out:
# 0    50.197472
# 1    44.900954
# 2    44.802867
# 3    36.195965
# 4    29.629630
# Name: PCT_Renter, dtype: float64

# %% [markdown]
# Plotting this data doesn't make the most amount of sense (as seen above) because these are not showing a linear pattern over time or a change. These data are more of a commparison between the tracts at a given time (2021). So, instead, I am going to try to looking at these percentages like the maps above.

# %%
tracts_tenure.plot(figsize=(12,10),
                 column='PCT_Renter',
                 legend=True, 
                 scheme='equal_interval')

plt.show()

# %% [markdown]
# Before, I looked at renter occupied units with equal intervals. Now, I will try out the natural break and quantiles options for visualizing to see if there are differences.

# %% [markdown]
# #### Folium Mapping
#
# Another opportunity to visualize some of the spatial data is in folium. I am first going to import the folium library, and then begin my viewing the specific census tracts that I selected in Philly.

# %%
import folium

# %% [markdown]
# Below, I am going to visualize both the tract level data for both the idenitifed Logan Neighborhood and the larger Philadelphia County. I plan to use the created variable for percent renter occupied on both chloropleth maps to show the gradient.

# %%
m = folium.Map(location=[+40.02, -75.14], 
               zoom_start = 12,
               tiles='CartoDB positron', 
               attribution='CartoDB')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efa538db62f107c5da9c846f5270734e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efa538db62f107c5da9c846f5270734e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efa538db62f107c5da9c846f5270734e = L.map(
#                 &quot;map_efa538db62f107c5da9c846f5270734e&quot;,
#                 {
#                     center: [40.02, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     attribution: &quot;CartoDB&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31ee516614c5a6e9969b80071f6c8ca7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_efa538db62f107c5da9c846f5270734e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# plot chorpleth over the base map
folium.Choropleth(
                  geo_data=tracts_housing, # geo data
                  data=tracts_housing, # data          
                  key_on='feature.properties.FIPS', # key, or merge column
                  columns=['FIPS', 'Housing Units'], # [key, value]
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.2, # line opacity (of the border)
                  legend_name='Housing Units in Logan Neighborhood (2021)').add_to(m)    # name on the legend color bar
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efa538db62f107c5da9c846f5270734e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efa538db62f107c5da9c846f5270734e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efa538db62f107c5da9c846f5270734e = L.map(
#                 &quot;map_efa538db62f107c5da9c846f5270734e&quot;,
#                 {
#                     center: [40.02, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     attribution: &quot;CartoDB&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31ee516614c5a6e9969b80071f6c8ca7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_efa538db62f107c5da9c846f5270734e);
#
#
#             var choropleth_576b2e600694d4d8964823285e543c32 = L.featureGroup(
#                 {}
#             ).addTo(map_efa538db62f107c5da9c846f5270734e);
#
#
#         function geo_json_b9238de23313dd2aed127bd0d580f2c3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#810f7c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bfd3e6&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8856a7&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ebcda&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#             }
#         }
#
#         function geo_json_b9238de23313dd2aed127bd0d580f2c3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b9238de23313dd2aed127bd0d580f2c3 = L.geoJson(null, {
#                 onEachFeature: geo_json_b9238de23313dd2aed127bd0d580f2c3_onEachFeature,
#
#                 style: geo_json_b9238de23313dd2aed127bd0d580f2c3_styler,
#         });
#
#         function geo_json_b9238de23313dd2aed127bd0d580f2c3_add (data) {
#             geo_json_b9238de23313dd2aed127bd0d580f2c3
#                 .addData(data)
#                 .addTo(choropleth_576b2e600694d4d8964823285e543c32);
#         }
#             geo_json_b9238de23313dd2aed127bd0d580f2c3_add({&quot;bbox&quot;: [-75.1595540696877, 40.0199675340755, -75.1312924891143, 40.0398459498705], &quot;features&quot;: [{&quot;bbox&quot;: [-75.1485693367055, 40.0206445733101, -75.1393063561356, 40.0317757569512], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-75.1416855923428, 40.0207568496675], [-75.1415915351569, 40.0208206084388], [-75.1413302801665, 40.0221010525539], [-75.1409810090472, 40.0236768326432], [-75.1406407157054, 40.0252717553908], [-75.1403066564792, 40.0267550626772], [-75.1399835001504, 40.0282543443416], [-75.139659340513, 40.0297457879568], [-75.1393063561356, 40.0312971368966], [-75.140105710581, 40.0314085614355], [-75.1408838562951, 40.0315019529555], [-75.1416707904026, 40.0316098838996], [-75.1423059616066, 40.0316856895701], [-75.1424039648329, 40.0317160004483], [-75.142472815056, 40.0317757569512], [-75.1433791525908, 40.0312832458493], [-75.1442862337168, 40.0308238617418], [-75.1453745745441, 40.0302349442855], [-75.146003539645, 40.029937506559], [-75.1466826387505, 40.0295739309641], [-75.1468527767935, 40.0294908851406], [-75.1469187705343, 40.0291200807551], [-75.1472213965253, 40.0276532238443], [-75.1475581855577, 40.0261476966156], [-75.1478968260833, 40.0245629137035], [-75.1482480748204, 40.0229687522717], [-75.1485693367055, 40.0214852045647], [-75.1471135589422, 40.0212895428797], [-75.1463811585416, 40.0212136214224], [-75.1455961017371, 40.021113222253], [-75.1448033745384, 40.0210065608575], [-75.1440160504589, 40.0209040657394], [-75.1432253632801, 40.0208055551301], [-75.1424444807812, 40.0206967476578], [-75.1420297609707, 40.0206445733101],

# %%
m.save('Logan_Triangle_Housing_Units.html')

# %% [markdown]
# ## Comparison to Philadelphia-County
#
# Now, I am going to try to map some of these same variables at the Philadelphia County level because Philadelphia has the same borders as Philadelphia County, and the dataset pulled from the City's database is at the County-level. I am going to run the same code that I did for the specific tracts and make comparisons.

# %%
dfpa.columns[dfpa.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_PUMA5',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE',
#  'Geo_UACP',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA1']

# %%
dfpa = dfpa.dropna(axis=1,how="all")

# %% [markdown]
# After an initial look at the columns and a drop of the variables that are empty, I am going to just keep the FIPS and the tenure data.

# %%
columns_to_keep_pa = ['Geo_FIPS',
                   'SE_A10008_001',
                   'SE_A10008_002',
                   'SE_A10008_003',
                   'SE_A10008_004',
                   'SE_A10008_005',
                   'SE_A10008_006',
                   'SE_A10008_007',
                   'SE_A10008_008',
                   'SE_A10008_009',
                   'SE_A10003_001',
                   'SE_B10060_001',
                   'SE_B10060_002',
                   'SE_B10060_003',
                   'SE_A10036_001',
                   'SE_A18009_001',
                   'SE_A10032_001',
                   'SE_A10032_002',
                   'SE_A10032_003',
                   'SE_A10032_004',
                   'SE_A10032_005',
                   'SE_A10032_006',
                   'SE_A10032_007',
                   'SE_A10032_008',
                   'SE_A10032_009',
                   'SE_A10032_010',
                   'SE_A10032_011',
                   'SE_A10032_012',
                   'SE_A10055_001',
                   'SE_A10055_002',
                   'SE_A10055_003',
                   'SE_A10055_004',
                   'SE_A10055_005',
                   'SE_A10055_006',
                   'SE_A10055_007',
                   'SE_A10055_008',
                   'SE_A10055_009',
                   'SE_A10055_010',
                   'SE_A10055_011',]

# %%
df2pa = dfpa[columns_to_keep_pa]

# %%
columns = list(df2pa)
columns
# Out:
# ['Geo_FIPS',
#  'SE_A10008_001',
#  'SE_A10008_002',
#  'SE_A10008_003',
#  'SE_A10008_004',
#  'SE_A10008_005',
#  'SE_A10008_006',
#  'SE_A10008_007',
#  'SE_A10008_008',
#  'SE_A10008_009',
#  'SE_A10003_001',
#  'SE_B10060_001',
#  'SE_B10060_002',
#  'SE_B10060_003',
#  'SE_A10036_001',
#  'SE_A18009_001',
#  'SE_A10032_001',
#  'SE_A10032_002',
#  'SE_A10032_003',
#  'SE_A10032_004',
#  'SE_A10032_005',
#  'SE_A10032_006',
#  'SE_A10032_007',
#  'SE_A10032_008',
#  'SE_A10032_009',
#  'SE_A10032_010',
#  'SE_A10032_011',
#  'SE_A10032_012',
#  'SE_A10055_001',
#  'SE_A10055_002',
#  'SE_A10055_003',
#  'SE_A10055_004',
#  'SE_A10055_005',
#  'SE_A10055_006',
#  'SE_A10055_007',
#  'SE_A10055_008',
#  'SE_A10055_009',
#  'SE_A10055_010',
#  'SE_A10055_011']

# %% [markdown]
# I will also rename the columns to more clearly show the content of the variables.

# %%
df2pa.columns = ['FIPS',
                   'Households',
                   'Family Households',
                   'Married-Couple Family',
                   'Other Family',
                   'Male Householder, No Wife Present',
                   'Female Householder, No Husband Present',
                   'Nonfamily Households',
                   'Male Householder',
                   'Female Householder',
                   'Average Household Size of Occupied Housing Units',
                   'Owner Occupied Housing Units',
                   'White Alone, Not Hispanic or Latino Homeowners of Owner Occupied Housing Units',
                   'Non-White Homeowners of Owner Occupied Housing Units',
                   'Median House Value for All Owner-Occupied Housing Units',
                   'Median Gross Rent in Renter-occupied housing units paying cash rent',
                   'Housing Units',
                   '1 Unit',
                   '1 Unit, Detached',
                   '1 Unit, Attached',
                   '2 Units',
                   '3 or 4 Units',
                   '5 to 9 Units',
                   '10 to 19 Units',
                   '20 to 49 Units',
                   '50 or More Units',
                   'Mobile Home',
                   'Boat, Rv, Van, Etc.',
                   'Occupied Housing Units',
                   'Occupied Housing Units: Built 2020 or Later',
                   'Occupied Housing Units: Built 2010 to 2019',
                   'Occupied Housing Units: Built 2000 to 2009',
                   'Occupied Housing Units: Built 1990 to 1999',
                   'Occupied Housing Units: Built 1980 to 1989',
                   'Occupied Housing Units: Built 1970 to 1979',
                   'Occupied Housing Units: Built 1960 to 1969',
                   'Occupied Housing Units: Built 1950 to 1959',
                   'Occupied Housing Units: Built 1940 to 1949',
                   'Occupied Housing Units: Built 1939 or Earlier',]

# %%
df2pa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 39 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   FIPS                                                                            408 non-null    object
#  1   Households                                                                      408 non-null    int64
#  2   Family Households                                                               408 non-null    int64
#  3   Married-Couple Family                                                           408 non-null    int64
#  4   Other Family                                                                    408 non-null    int64
#  5   Male Householder, No Wife Present                                               408 non-null    int64
#  6   Female Householder, No Husband Present                                          408 non-null    int64
#  7   Nonfamily Households                                                            408 non-null    int64
#  8   Male Householder                                                                408 non-null    int64
#  9   Female Householder                                                              408 non-null    int64
#  10  Average Household Size of Occupied Housing Units                                388 non-null    float64
#  11  Owner Occupied Housing Units                                                    408 non-null    int64
#  12  White Alone, Not Hispanic or Latino Homeowners of Owner Occupied Housing Units  408 non-null    int64
#  13  Non-White Homeowners of Owner Occupied Housing Units                            408 non-null    int64
#  14  Median House Value for All Owner-Occupied Housing Units                         375 non-null    float64
#  15  Median Gross Rent in Renter-occupied housing units paying cash rent             383 non-null    float64
#  16  Housing Units                                                                   408 non-null    int64
#  17  1 Unit                                                                          408 non-null    int64
#  18  1 Unit, Detached                                                                408 non-null    int64
#  19  1 Unit, Attached                                                                408 non-null    int64
#  20  2 Units                                                                         408 non-null    int64
#  21  3 or 4 Units                                                                    408 non-null    int64
#  22  5 to 9 Units                                                                    408 non-null    int64
#  23  10 to 19 Units                                                                  408 non-null    int64
#  24  20 to 49 Units                                                                  408 non-null    int64
#  25  50 or More Units                                                                408 non-null    int64
#  26  Mobile Home                                                                     408 non-null    int64
#  27  Boat, Rv, Van, Etc.                                                             408 non-null    int64
#  28  Occupied Housing Units                                                          408 non-null    int64
#  29  Occupied Housing Units: Built 2020 or Later                                     408 non-null    int64
#  30  Occupied Housing Units: Built 2010 to 2019                                      408 non-null    int64
#  31  Occupied Housing Units: Built 2000 to 2009                                      408 non-null    int64
#  32  Occupied Housing Units: Built 1990 to 1999                                      408 non-null    int64
#  33  Occupied Housing Units: Built 1980 to 1989                                      408 non-null    int64
#  34  Occupied Housing Units: Built 1970 to 1979                                      408 non-null    int64
#  35  Occupied Housing Units: Built 1960 to 1969                                      408 non-null    int64
#  36  Occupied Housing Units: Built 1950 to 1959                                      408 non-null    int64
#  37  Occupied Housing Units: Built 1940 to 1949                                      408 non-null    int64
#  38  Occupied Housing Units: Built 1939 or Earlier                                   408 non-null    int64
# dtypes: float64(3), int64(35), object(1)
# memory usage: 124.4+ KB

# %% [markdown]
# Similar to above, I am going to merge the two datasets based on the common variable -- 'FIPS'.

# %%
pa_housing= tracts.merge(df2pa,on='FIPS')

# %% [markdown]
# Now, to get a better sense of the percentage of renters in a specific tract, I am going to create a new variable for the percentage of owners and renters in a given tract.

# %%
pa_tenure['PCT_Renter'] = pa_tenure['Renter Occupied']/pa_tenure['Occupied Housing Units']*100
pa_tenure['PCT_Owner'] = pa_tenure['Owner Occupied']/pa_tenure['Occupied Housing Units']*100

# %% [markdown]
# Using the folium mapping functions, I am going to map out the county-level tenure data.

# %%
m = folium.Map(location=[+40.02, -75.14], 
               zoom_start = 10,
               tiles='CartoDB positron', 
               attribution='CartoDB')

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7e61e7ca0fe192c87f92fe9c3c44b7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7e61e7ca0fe192c87f92fe9c3c44b7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7e61e7ca0fe192c87f92fe9c3c44b7e = L.map(
#                 &quot;map_a7e61e7ca0fe192c87f92fe9c3c44b7e&quot;,
#                 {
#                     center: [40.02, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     attribution: &quot;CartoDB&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc9f1e419181e54226574f38b6ea058f = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a7e61e7ca0fe192c87f92fe9c3c44b7e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[+40.02, -75.14], 
               zoom_start = 10,
               tiles='CartoDB positron', 
               attribution='CartoDB')

folium.Choropleth(
                  geo_data=pa_housing, # geo data
                  data=pa_housing, # data          
                  key_on='feature.properties.FIPS', # key, or merge column
                  columns=['FIPS', 'Housing Units'], # [key, value]
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.2, # line opacity (of the border)
                  legend_name='Housing Units in Philadelphia (2021)').add_to(m)    # name on the legend color bar
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_275363ce545734ee7e598d5831207906 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_275363ce545734ee7e598d5831207906&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_275363ce545734ee7e598d5831207906 = L.map(
#                 &quot;map_275363ce545734ee7e598d5831207906&quot;,
#                 {
#                     center: [40.02, -75.14],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     attribution: &quot;CartoDB&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53305a0b6cd22311b866b5bd35865b30 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_275363ce545734ee7e598d5831207906);
#
#
#             var choropleth_e443ec4f11e4afcdf602e40872845c9d = L.featureGroup(
#                 {}
#             ).addTo(map_275363ce545734ee7e598d5831207906);
#
#
#         function geo_json_3bb217b9e2e6f1dec4be828f2ead4773_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;5&quot;: case &quot;13&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;24&quot;: case &quot;29&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;54&quot;: case &quot;58&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;70&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;90&quot;: case &quot;92&quot;: case &quot;96&quot;: case &quot;97&quot;: case &quot;106&quot;: case &quot;111&quot;: case &quot;113&quot;: case &quot;125&quot;: case &quot;132&quot;: case &quot;134&quot;: case &quot;136&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;143&quot;: case &quot;148&quot;: case &quot;150&quot;: case &quot;152&quot;: case &quot;155&quot;: case &quot;157&quot;: case &quot;160&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;163&quot;: case &quot;168&quot;: case &quot;169&quot;: case &quot;170&quot;: case &quot;172&quot;: case &quot;173&quot;: case &quot;175&quot;: case &quot;176&quot;: case &quot;184&quot;: case &quot;187&quot;: case &quot;192&quot;: case &quot;193&quot;: case &quot;195&quot;: case &quot;196&quot;: case &quot;197&quot;: case &quot;198&quot;: case &quot;199&quot;: case &quot;201&quot;: case &quot;202&quot;: case &quot;203&quot;: case &quot;206&quot;: case &quot;211&quot;: case &quot;213&quot;: case &quot;215&quot;: case &quot;216&quot;: case &quot;218&quot;: case &quot;224&quot;: case &quot;227&quot;: case &quot;244&quot;: case &quot;246&quot;: case &quot;247&quot;: case &quot;249&quot;: case &quot;253&quot;: case &quot;254&quot;: case &quot;255&quot;: case &quot;259&quot;: case &quot;265&quot;: case &quot;266&quot;: case &quot;268&quot;: case &quot;269&quot;: case &quot;271&quot;: case &quot;276&quot;: case &quot;277&quot;: case &quot;278&quot;: case &quot;279&quot;: case &quot;281&quot;: case &quot;282&quot;: case &quot;283&quot;: case &quot;287&quot;: case &quot;292&quot;: case &quot;294&quot;: case &quot;299&quot;: case &quot;300&quot;: case &quot;301&quot;: case &quot;302&quot;: case &quot;303&quot;: case &quot;309&quot;: case &quot;320&quot;: case &quot;324&quot;: case &quot;329&quot;: case &quot;330&quot;: case &quot;332&quot;: case &quot;334&quot;: case &quot;335&quot;: case &quot;336&quot;: case &quot;337&quot;: case &quot;338&quot;: case &quot;339&quot;: case &quot;346&quot;: case &quot;351&quot;: case &quot;352&quot;: case &quot;355&quot;: case &quot;357&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8c96c6&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 case &quot;3&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;16&quot;: case &quot;23&quot;: case &quot;28&quot;: case &quot;36&quot;: case &quot;43&quot;: case &quot;45&quot;: case &quot;56&quot;: case &quot;59&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;72&quot;: case &quot;86&quot;: case &quot;93&quot;: case &quot;102&quot;: case &quot;104&quot;: case &quot;118&quot;: case &quot;140&quot;: case &quot;149&quot;: case &quot;164&quot;: case &quot;171&quot;: case &quot;180&quot;: case &quot;182&quot;: case &quot;214&quot;: case &quot;220&quot;: case &quot;222&quot;: case &quot;229&quot;: case &quot;234&quot;

# %%
m.save('Philadelphia_HousingUnits.html')

# %% [markdown]
# In the initial look over the map, it seems like the tracts with the higher percentage of renters are concentrated around downtown Philadelphia, and running out specifically along N Broad. In looking at the tracts that make up the Logan Neighborhood, there are actually lower percentages of renters than in adjacent tracts. The tracts range from 17-67% of renters. It makes me wonder, knowing the history of the neighborhood, if the owners are longtime owners. The neighborhood is not facing gentrification, and because of the immediate environmental harms, there is not new construction happening.

# %% [markdown]
# ### Static Maps

# %% [markdown]
# Now that I have had a chance to get a sense of the data both at the tract-level and at the city-level, I want to make some pretty maps!!! The dataset I will use for the neighborhood around the Logan Triangle is tracts_tenure. The dataset I will use for the entire Philadelphia area is pa_tenure.

# %% [markdown]
# #### Logan Neighborhood
#
# I am going to map the percentage of renter occupied units in the Logan Neighborhood. I want to make it pretty, so I am going to change the color-scheme to be a more muted palette. I am also going to create a horizontal legend and remove the axes to make the map cleaner.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
ax1 =tracts_housing.plot(column='Housing Units',
                   legend=True,
  legend_kwds={'label': "Housing Units in Logan Neighborhood",
                        'orientation': "horizontal"},
               cmap='GnBu');

ax1.set_axis_off()
plt.savefig("logan housing unit map.pdf", transparent=True)

# %% [markdown]
# #### Philadelphia
#
# As a comparison, I am going to map the percentage of renter occupied units in Philadelphia. Similar to above, I am going to more to a more muted palette. I am also going to create a horizontal legend and remove the axes to make the map cleaner.

# %% [markdown]
# As seen above, the two census tracts with the highest percentage of renters are in the center of the neighborhood. However, these areas still have up to half of their occupied units as renter occupied.

# %%
ax2 = pa_housing.plot(column='Housing Units',
                   legend=True,
  legend_kwds={'label': "Housing Units in Philadelphia",
                        'orientation': "horizontal"},
               cmap='GnBu');
ax2.set_axis_off()
plt.savefig("philadelphia housing unit map.pdf", transparent=True)

# %% [markdown]
# As a point of comparison, the map of all of Philadelphia shows that there are tracts that have a much higher amount of housing units (density). There are also many tracts that have a much lower density, specifically in the northwest.
